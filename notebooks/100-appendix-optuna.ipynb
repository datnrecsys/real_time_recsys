# %%
import os

train_data_fp: str = os.path.abspath("../data_for_ai/interim/train_sample_interactions_16407u_neg_seq.parquet")
val_data_fp: str = os.path.abspath("../data_for_ai/interim/val_sample_interactions_16407u_neg_seq.parquet")

# %%
import pandas as pd

train_df = pd.read_parquet(train_data_fp)

# %%
train_df
# Out:
#                              user_id parent_asin  rating  \
# 151343  AEEV5YWQKPBTLFWHKOBBULYA2RDQ  B009RUZ7TS     0.0
# 40958   AF7KZV4NJ5GBDVFTB7PEEUN4U53A  B0BBMLD8QT     5.0
# 218918  AFVQ4K4KZPLQ3E2VFYSGX6HFXGNQ  B0BB6R89VF     0.0
# 43115   AFCLWJMGYFCOJQR7T4454OF5A5WA  B00ENFP224     5.0
# 233421  AFP4PHJ6Q2RRXLDPSDSH6VXJRUTA  B07CMXS5FP     0.0
# ...                              ...         ...     ...
# 250960  AGQHC7YNLYP4QV2PSBD6URSMJSVA  B07H65KP63     0.0
# 217058  AHD65JAOVTTPDNJWOLSSGS3QVK6Q  B07DKMJ61N     0.0
# 61324   AF32PWYNLPCVAU4UX35IEAZOFA3Q  B011BRUOMO     5.0
# 132003  AGM65FYYAPHOLESGIDMFMPUQIYNA  B0016BVDIK     0.0
# 34752   AFVQ4K4KZPLQ3E2VFYSGX6HFXGNQ  B00DR0B6XK     4.0
#
#                      timestamp  user_indice  item_indice  \
# 151343 2014-07-17 19:15:55.000         1412         4220
# 40958  2015-07-29 20:38:06.000         4871         4476
# 218918 2017-12-13 20:35:02.334         7616         1218
# ...

# %%
with pd.option_context("display.max_colwidth", None):
    display(train_df.loc[lambda df: df["user_id"] == "AF7KZV4NJ5GBDVFTB7PEEUN4U53A"].sort_values("timestamp"))
# Out:
#                              user_id parent_asin  rating  \
# 171046  AF7KZV4NJ5GBDVFTB7PEEUN4U53A  B00R43VK5A     0.0
# 40175   AF7KZV4NJ5GBDVFTB7PEEUN4U53A  B00R43VK5A     5.0
# 40958   AF7KZV4NJ5GBDVFTB7PEEUN4U53A  B0BBMLD8QT     5.0
# 171829  AF7KZV4NJ5GBDVFTB7PEEUN4U53A  B0BBMLD8QT     0.0
# 47655   AF7KZV4NJ5GBDVFTB7PEEUN4U53A  B09RS2KZK4     5.0
# 178526  AF7KZV4NJ5GBDVFTB7PEEUN4U53A  B09RS2KZK4     0.0
# 179693  AF7KZV4NJ5GBDVFTB7PEEUN4U53A  B00FB50SBU     0.0
# 48822   AF7KZV4NJ5GBDVFTB7PEEUN4U53A  B00FB50SBU     5.0
# 188148  AF7KZV4NJ5GBDVFTB7PEEUN4U53A  B00IVPU7AO     0.0
# 57277   AF7KZV4NJ5GBDVFTB7PEEUN4U53A  B00IVPU7AO     5.0
# 83707   AF7KZV4NJ5GBDVFTB7PEEUN4U53A  B07WMB4XS4     5.0
# 214578  AF7KZV4NJ5GBDVFTB7PEEUN4U53A  B07WMB4XS4     0.0
# 244180  AF7KZV4NJ5GBDVFTB7PEEUN4U53A  B07N86MCD2     0.0
# 113309  AF7KZV4NJ5GBDVFTB7PEEUN4U53A  B07N86MCD2     5.0
# 248552  AF7KZV4NJ5GBDVFTB7PEEUN4U53A  B07HZLHPKP     0.0
# ...

# %%
val_df = pd.read_parquet(val_data_fp)

# %%
val_df.groupby("user_id").size().sort_values(ascending=False).index[0]
# Out:
# 'AFKERAMSXU4MWO3H53R7DEFOHUVQ'

# %%
with pd.option_context("display.max_colwidth", None):
    display(val_df.loc[lambda df: df["user_id"] == "AFKERAMSXU4MWO3H53R7DEFOHUVQ"].sort_values("timestamp"))
# Out:
#                              user_id parent_asin  rating  \
# 259378  AFKERAMSXU4MWO3H53R7DEFOHUVQ  B07ZZVX1F2     0.0
# 128507  AFKERAMSXU4MWO3H53R7DEFOHUVQ  B07ZZVX1F2     5.0
# 259461  AFKERAMSXU4MWO3H53R7DEFOHUVQ  B07G5YXYFL     0.0
# 128590  AFKERAMSXU4MWO3H53R7DEFOHUVQ  B07G5YXYFL     5.0
# 129149  AFKERAMSXU4MWO3H53R7DEFOHUVQ  B07GZFM1ZM     4.0
# 260020  AFKERAMSXU4MWO3H53R7DEFOHUVQ  B07GZFM1ZM     0.0
# 129491  AFKERAMSXU4MWO3H53R7DEFOHUVQ  B0BCPC68J6     5.0
# 260362  AFKERAMSXU4MWO3H53R7DEFOHUVQ  B0BCPC68J6     0.0
# 260389  AFKERAMSXU4MWO3H53R7DEFOHUVQ  B08F1P3BCC     0.0
# 129518  AFKERAMSXU4MWO3H53R7DEFOHUVQ  B08F1P3BCC     5.0
# 260447  AFKERAMSXU4MWO3H53R7DEFOHUVQ  B01J2G4VBG     0.0
# 129576  AFKERAMSXU4MWO3H53R7DEFOHUVQ  B01J2G4VBG     5.0
# 130172  AFKERAMSXU4MWO3H53R7DEFOHUVQ  B08J9NQ6CS     4.0
# 261043  AFKERAMSXU4MWO3H53R7DEFOHUVQ  B08J9NQ6CS     0.0
# 261154  AFKERAMSXU4MWO3H53R7DEFOHUVQ  B01N9O3UTF     0.0
# ...
