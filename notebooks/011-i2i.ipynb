# %% [markdown]
# ## Setup

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import numpy as np
from pydantic import BaseModel
import sys
import os
import mlflow
from loguru import logger
from load_dotenv import load_dotenv
import time
import json

sys.path.insert(0, "..")

from src.utils.embedding_id_mapper import IDMapper
from src.algo.cf_i2i import I2ICollaborativeFiltering
from src.eval.utils import create_rec_df, create_label_df, merge_recs_with_target
from src.eval.log_metrics import log_ranking_metrics, log_classification_metrics

# %%
_ = load_dotenv(override = True)

# %% [markdown]
# ## Arguments

# %%
# Tag this cell as `parameters`
top_n = 10
min_sim_count=4

# %%
class Args(BaseModel):
    testing: bool = False
    log_to_mlflow: bool = True
    experiment_name: str = "first-attempt"
    run_name: str = f"003-i2i-cf-min-sim-count={min_sim_count}"
    notebook_persit_dp: str = None
    group_name: str = "i2i-cf"
    
    user_col: str = "user_id"
    item_col: str = "parent_asin"
    rating_col: str = "rating"
    timestamp_col: str = "timestamp"

    top_K: int = 100
    top_k: int = 10
    min_sim_count: int = min_sim_count

    train_data_fp: str = os.path.abspath("../data_for_ai/interim/train_sample_interactions_16407u.parquet")
    val_data_fp: str = os.path.abspath("../data_for_ai/interim/val_sample_interactions_16407u.parquet")

    def init(self):
        self.notebook_persit_dp = os.path.abspath(f"data/{self.experiment_name}/{self.run_name}")

        if not os.environ.get("MLFLOW_TRACKING_URI"):
            self.log_to_mlflow = False
            logger.warning("MLFlow is not enabled. Turn off tracking to Mlflow.")

        if self.log_to_mlflow:
            logger.info(
                f"Setting up Mlflow experiment: {self.experiment_name}, run_name: {self.run_name}"
            )

            mlflow.set_experiment(self.experiment_name)
            mlflow.start_run(run_name=self.run_name)

        if not self.testing:
            os.makedirs(self.notebook_persit_dp, exist_ok=True)
        return self
    
args = Args().init()
print(args.model_dump_json(indent=2))
# Out:
# 2025-04-09 15:34:52.251 | INFO     | __main__:init:27 - Setting up Mlflow experiment: first-attempt, run_name: 003-i2i-cf-min-sim-count=4
# {
#   "testing": false,
#   "log_to_mlflow": true,
#   "experiment_name": "first-attempt",
#   "run_name": "003-i2i-cf-min-sim-count=4",
#   "notebook_persit_dp": "/home/dinhln/Desktop/real_time_recsys/notebooks/data/first-attempt/003-i2i-cf-min-sim-count=4",
#   "user_col": "user_id",
#   "item_col": "parent_asin",
#   "rating_col": "rating",
#   "timestamp_col": "timestamp",
#   "top_K": 100,
#   "top_k": 10,
#   "train_data_fp": "/home/dinhln/Desktop/real_time_recsys/data_for_ai/interim/train_sample_interactions_16407u.parquet",
#   "val_data_fp": "/home/dinhln/Desktop/real_time_recsys/data_for_ai/interim/val_sample_interactions_16407u.parquet"
# }

# %% [markdown]
# ## Load data

# %%
train_df = pd.read_parquet(args.train_data_fp)
val_df = pd.read_parquet(args.val_data_fp)

assert set(val_df[args.user_col].unique()).issubset(set(train_df[args.user_col].unique())), "Validation users must be present in training users."
assert set(val_df[args.item_col].unique()).issubset(set(train_df[args.item_col].unique())), "Validation items must be present in training items."
assert train_df[args.timestamp_col].max() < val_df[args.timestamp_col].min(), "Validation data must be after training data. Otherwise, its a data contamination problem."

# %%
train_df.head(3)
# Out:
#                            user_id parent_asin  rating           timestamp
# 3194  AEYGPUCRKH7G4VM22FM3VAKSQ23Q  B06XKCPK5W     2.0 2012-06-11 16:41:10
# 3199  AEYGPUCRKH7G4VM22FM3VAKSQ23Q  B000CKVOOY     3.0 2012-08-02 02:04:13
# 3200  AEYGPUCRKH7G4VM22FM3VAKSQ23Q  B006GWO5WK     5.0 2012-09-15 16:34:46

# %% [markdown]
# ## Convert user_id and item_id to indices

# %%
idm_path = os.path.abspath("../data_for_ai/interim/idm_16407u.json")
idm = IDMapper().load(idm_path)
idm.get_user_id(1)
# Out:
# 'AE227WAM4NWQPJI33OPN7ZARNNZQ'

# %%
train_df = train_df.pipe(idm.map_indices)
val_df = val_df.pipe(idm.map_indices)

assert idm.unknown_item_index not in train_df["item_indice"].values, "Unknown item index must be present in training data."
assert idm.unknown_user_index not in train_df["user_indice"].values, "Unknown user index must be present in training data."
assert idm.unknown_item_index not in val_df["item_indice"].values, "Unknown item index must be present in validation data."
assert idm.unknown_user_index not in val_df["user_indice"].values, "Unknown user index must be present in validation data."

# %%
train_df.head(3)
# Out:
#                            user_id parent_asin  rating           timestamp  \
# 3194  AEYGPUCRKH7G4VM22FM3VAKSQ23Q  B06XKCPK5W     2.0 2012-06-11 16:41:10
# 3199  AEYGPUCRKH7G4VM22FM3VAKSQ23Q  B000CKVOOY     3.0 2012-08-02 02:04:13
# 3200  AEYGPUCRKH7G4VM22FM3VAKSQ23Q  B006GWO5WK     5.0 2012-09-15 16:34:46
#
#       user_indice  item_indice
# 3194         3931         2905
# 3199         3931           89
# 3200         3931          758

# %%
assert train_df.groupby(args.user_col)[args.item_col].nunique().min() >= 5, "Each user must have at least five items."
assert train_df.groupby(args.item_col)[args.user_col].nunique().min() >= 10, "Each item must have at least ten users."

# %% [markdown]
# ## Init model

# %%
def init_model(n_users, n_items):
    model = I2ICollaborativeFiltering(n_users, n_items)
    return model

# %% [markdown]
# ## Overfit 1 batch

# %%
train_overfit_df = train_df.loc[lambda df: df["user_indice"].lt(20) & df["item_indice"].lt(1000)]

# %% [markdown]
# ## Train model

# %%
users = train_df["user_indice"].values
items = train_df["item_indice"].values
rating = train_df["rating"].values

n_users = train_df["user_indice"].nunique()
n_items = train_df["item_indice"].nunique()

logger.info(f"Number of users: {n_users}, Number of items: {n_items}")
# Out:
# 2025-04-09 14:52:53.049 | INFO     | __main__:<module>:8 - Number of users: 16407, Number of items: 4817

# %%
# Calculate the upper bound loss, the loss that we wanna beat
mean_rating = np.mean(rating)

naive_mse = (
    (
        val_df["rating"] 
        - val_df.assign(naive_pred = mean_rating)["naive_pred"]
    )
    .apply(lambda x: x ** 2)
    .mean()
)
logger.info(f"Naive MSE: {naive_mse} given mean rating: {mean_rating}")
# Out:
# 2025-04-09 14:52:54.812 | INFO     | __main__:<module>:12 - Naive MSE: 1.8868801583202892 given mean rating: 4.403243531775936

# %% [markdown]
# ### Training

# %%
start_time = time.time()

model = init_model(n_users, n_items)
model.fit(users, items, rating)

end_time = time.time()
execution_time = end_time - start_time
logger.info(f"Execution time: {execution_time:.2f} seconds")
# Out:
# 2025-04-09 14:52:59.746 | INFO     | __main__:<module>:8 - Execution time: 3.35 seconds

# %% [markdown]
# # Test predict

# %%
val_sample_df = val_df.sample(1)
sample_user = val_sample_df["user_indice"].values
sample_item = val_sample_df["item_indice"].values
sample_rating = val_sample_df["rating"].values

logger.info(f"Sample user: {sample_user}, Sample item: {sample_item}, Sample rating: {sample_rating}")
model.predict(sample_user, sample_item, logging=True)
# Out:
# 2025-04-09 15:00:07.658 | INFO     | __main__:<module>:6 - Sample user: [7095], Sample item: [4383], Sample rating: [2.]
# 2025-04-09 15:00:07.659 | DEBUG    | src.algo.cf_i2i:forward:63 - Item 4383 has no similar items. Return 0 instead.
# array([0.5])

# %%
model.predict([7095], [3588], logging=True, min_sim_count=3)
# Out:
# 2025-04-09 15:00:39.053 | DEBUG    | src.algo.cf_i2i:forward:82 - Item sim: [0.02969833 0.01686759 0.01126714 0.         0.         0.
#  0.         0.         0.         0.        ]
# 2025-04-09 15:00:39.054 | DEBUG    | src.algo.cf_i2i:forward:83 - User rating: [5. 5. 5. 5. 5. 5. 5. 1. 1. 5.]
# 2025-04-09 15:00:39.055 | DEBUG    | src.algo.cf_i2i:forward:84 - Logit: 5.0
# array([0.99330715])

# %%
model.recommend(sample_user, keep_interacted=False, k=args.top_K, min_sim_count=3)
# Out:
# Recommending items:   0%|          | 0/1 [00:00<?, ?user/s]
# {'user_indice': [7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095,
#   7095],
#  'recommendation': [4419,
#   4435,
#   2450,
#   3585,
#   3586,
#   1348,
#   162,
#   3588,
#   2154,
#   340,
#   3944,
#   1768,
#   2146,
#   4434,
#   1104,
#   1998,
#   770,
#   4625,
#   4624,
#   858,
#   3211,
#   4621,
#   2869,
#   3937,
#   4617,
#   2135,
#   2477,
#   4443,
#   4611,
#   2615,
#   4123,
#   2162,
#   2629,
#   152,
#   1974,
#   1326,
#   509,
#   120,
#   1976,
#   1477,
#   3855,
#   3959,
#   1474,
#   127,
#   4412,
#   352,
#   131,
#   4417,
#   1986,
#   4518,
#   1126,
#   3571,
#   4023,
#   1469,
#   781,
#   3024,
#   4423,
#   3576,
#   3578,
#   4424,
#   4120,
#   2008,
#   3869,
#   529,
#   3240,
#   3697,
#   2036,
#   3885,
#   1533,
#   2811,
#   3645,
#   2043,
#   3887,
#   1055,
#   2531,
#   4493,
#   1601,
#   2816,
#   2536,
#   3894,
#   3657,
#   1047,
#   3908,
#   3272,
#   4531,
#   3271,
#   1042,
#   3907,
#   3665,
#   4507,
#   262,
#   2824,
#   3051,
#   2847,
#   193,
#   2806,
#   3717,
#   851,
#   1839,
#   2859],
#  'score': [0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153,
#   0.9933071490757153]}

# %% [markdown]
# ## Evaluate

# %% [markdown]
# ### Recommendation metrics

# %%
val_user_indices = val_df["user_indice"].unique()
logger.info(f"Number of users in validation set: {len(val_user_indices)}")
# Out:
# 2025-04-09 15:07:40.299 | INFO     | __main__:<module>:2 - Number of users in validation set: 2424

# %%
val_user_indices
# Out:
# array([12159,   870, 13529, ...,  5497,  6427,  2423])

# %%
recommendations = model.recommend(val_user_indices, keep_interacted=True, top_n= top_n ,k=args.top_K, min_sim_count=args.min_sim_count)
# Out:
# Recommending items:   0%|          | 0/2424 [00:00<?, ?user/s]

# %%
rec_df = pd.DataFrame(recommendations).pipe(create_rec_df, idm = idm)
rec_df.head(3)
# Out:
#    user_indice  recommendation     score  rec_ranking  \
# 0        12159            2779  0.992503          1.0
# 1        12159            3719  0.991558          2.0
# 2        12159            1925  0.991164          3.0
#
#                         user_id parent_asin
# 0  AGZE3IYHOEGKUTJZSQCSFSQ4IFFQ  B01M7VOJFW
# 1  AGZE3IYHOEGKUTJZSQCSFSQ4IFFQ  B07VJQ5VBV
# 2  AGZE3IYHOEGKUTJZSQCSFSQ4IFFQ  B00R92CL5E

# %%
rec_df.loc[rec_df["user_id"] == "AHZZM7BCJAF2UEMMBHZCLXBB2SVA"]
# Out:
#         user_indice  recommendation     score  rec_ranking  \
# 210000        16403            4242  0.993307          1.0
# 210001        16403            3271  0.993307          2.0
# 210002        16403            3089  0.993307          3.0
# 210003        16403            4516  0.993307          4.0
# 210004        16403            2811  0.993307          5.0
# ...             ...             ...       ...          ...
# 210095        16403            1532  0.500000         96.0
# 210096        16403            1525  0.500000         97.0
# 210097        16403            1526  0.500000         98.0
# 210098        16403            1527  0.500000         99.0
# 210099        16403            1528  0.500000        100.0
#
#                              user_id parent_asin
# 210000  AHZZM7BCJAF2UEMMBHZCLXBB2SVA  B09LSJS48Q
# 210001  AHZZM7BCJAF2UEMMBHZCLXBB2SVA  B07C1263TQ
# 210002  AHZZM7BCJAF2UEMMBHZCLXBB2SVA  B075X8471B
# 210003  AHZZM7BCJAF2UEMMBHZCLXBB2SVA  B0BGNG1294
# 210004  AHZZM7BCJAF2UEMMBHZCLXBB2SVA  B01MTF2Z37
# ...                              ...         ...
# 210095  AHZZM7BCJAF2UEMMBHZCLXBB2SVA  B00IF70R7Q
# 210096  AHZZM7BCJAF2UEMMBHZCLXBB2SVA  B00ICDAAXO
# 210097  AHZZM7BCJAF2UEMMBHZCLXBB2SVA  B00ICDABYC
# 210098  AHZZM7BCJAF2UEMMBHZCLXBB2SVA  B00IEM6DBG
# 210099  AHZZM7BCJAF2UEMMBHZCLXBB2SVA  B00IEYHMPK
#
# [100 rows x 6 columns]

# %%
label_df = create_label_df(val_df)
label_df
# Out:
#                                user_id parent_asin  rating  rating_rank
# 12855326  AEMYBWDN67IB5IBTMHLHN76V4QHQ  B091K4WYD1     4.0          1.0
# 4327569   AEJIJK6DNQRSGOSMSRTSIVHKEWRQ  B07KTYJ769     5.0          1.0
# 18287739  AHQSVMSTGTE5YW577ATYHRWWA3EQ  B07GZFM1ZM     3.0          1.0
# 5917697   AFQWFCSD3NNG5LIG6SO7DCUKCIJA  B08F1P3BCC     5.0          1.0
# 10962783  AGVPCCFOHWKJOO5B6G266N2ZHALQ  B09K4R9KDM     5.0          1.0
# ...                                ...         ...     ...          ...
# 3348993   AFIGGCK7HZAP24TECVJXGOFP5IIA  B09G3MBH6V     1.0          8.0
# 7915094   AGSP5XAQPQBUUXZHEZSC65FD7NOQ  B004FV4ROA     1.0          8.0
# 3832028   AFKERAMSXU4MWO3H53R7DEFOHUVQ  B08J9NQ6CS     4.0          9.0
# 2102221   AEN2KQVSR5TWRXNQS3OTFT4EZQCA  B0BRT7XFM5     5.0          9.0
# 3832022   AFKERAMSXU4MWO3H53R7DEFOHUVQ  B07GZFM1ZM     4.0         10.0
#
# [3479 rows x 4 columns]

# %%
label_df.loc[label_df["user_id"] == "AHZZM7BCJAF2UEMMBHZCLXBB2SVA"]
# Out:
#                                user_id parent_asin  rating  rating_rank
# 19254013  AHZZM7BCJAF2UEMMBHZCLXBB2SVA  B075QC3TZY     1.0          1.0

# %%
eval_df = merge_recs_with_target(rec_df, label_df, k=args.top_K)
eval_df
# Out:
#         user_indice  recommendation     score  rec_ranking  \
# 78              8.0          4243.0  0.993307            1
# 13              8.0           785.0  0.993307            2
# 73              8.0          4106.0  0.993307            3
# 48              8.0          3074.0  0.993307            4
# 58              8.0          3286.0  0.993307            5
# ...             ...             ...       ...          ...
# 245541      16403.0          1525.0  0.500000           97
# 245542      16403.0          1526.0  0.500000           98
# 245543      16403.0          1527.0  0.500000           99
# 245544      16403.0          1528.0  0.500000          100
# 245616          NaN             NaN       NaN          101
#
#                              user_id parent_asin  rating  rating_rank
# 78      AE24AB4DW5KYK3F5DYOT5VPW2VLA  B09LYWCHJX       0          NaN
# 13      AE24AB4DW5KYK3F5DYOT5VPW2VLA  B006ZT4VA0       0          NaN
# 73      AE24AB4DW5KYK3F5DYOT5VPW2VLA  B092WMCV57       0          NaN
# 48      AE24AB4DW5KYK3F5DYOT5VPW2VLA  B075JZNHTD       0          NaN
# 58      AE24AB4DW5KYK3F5DYOT5VPW2VLA  B07C5QRJZD       0          NaN
# ...                              ...         ...     ...          ...
# 245541  AHZZM7BCJAF2UEMMBHZCLXBB2SVA  B00ICDAAXO       0          NaN
# 245542  AHZZM7BCJAF2UEMMBHZCLXBB2SVA  B00ICDABYC       0          NaN
# 245543  AHZZM7BCJAF2UEMMBHZCLXBB2SVA  B00IEM6DBG       0          NaN
# 245544  AHZZM7BCJAF2UEMMBHZCLXBB2SVA  B00IEYHMPK       0          NaN
# 245616  AHZZM7BCJAF2UEMMBHZCLXBB2SVA  B075QC3TZY       1          1.0
#
# [245638 rows x 8 columns]

# %%
ranking_report = log_ranking_metrics(args, eval_df)

# %%
ranking_report.as_dict()
# Out:
# {'metrics': [{'metric': 'NDCGKMetric',
#    'result': {'k': 10,
#     'current': 1     0.001650
#     2     0.001751
#     3     0.001877
#     4     0.001972
#     5     0.002207
#     6     0.002269
#     7     0.002407
#     8     0.002537
#     9     0.002661
#     10    0.003138
#     dtype: float64,
#     'current_value': 0.002661314577453662,
#     'reference': None,
#     'reference_value': None}},
#   {'metric': 'RecallTopKMetric',
#    'result': {'k': 100, 'current': 0     0.001238
#     1     0.001856
#     2     0.002063
#     3     0.002269
#     4     0.002716
#             ...
#     95    0.061765
#     96    0.062315
#     97    0.062522
#     98    0.062934
#     99    0.063278
#     Length: 100, dtype: float64, 'current_value': 0.06327793493635078, 'reference': None, 'reference_value': None}},
#   {'metric': 'PrecisionTopKMetric',
#    'result': {'k': 100,
#     'current': 0     0.001650
#     1     0.001238
#     2     0.000963
#     3     0.000825
#     4     0.000908
#             ...
#     95    0.000975
#     96    0.000974
#     97    0.000972
#     98    0.000967
#     99    0.000965
#     Length: 100, dtype: float64,
#     'current_value': 0.0009653465346534653,
#     'reference': None,
#     'reference_value': None}},
#   {'metric': 'FBetaTopKMetric',
#    'result': {'k': 10, 'current': 0    0.001414
#     1    0.001485
#     2    0.001313
#     3    0.001210
#     4    0.001361
#     5    0.001277
#     6    0.001239
#     7    0.001205
#     8    0.001176
#     9    0.001378
#     dtype: float64, 'current_value': 0.0013783422833808805, 'reference': None, 'reference_value': None}},
#   {'metric': 'PersonalizationMetric',
#    'result': {'k': 10,
#     'current_value': 0.9903230727530037,
#     'current_table': {'B01K8B8YA8': 978,
#      'B07S764D9V': 973,
#      'B075X8471B': 965,
#      'B00JO6RO8C': 929,
#      'B0BGNG1294': 911,
#      'B011BRUOMO': 826,
#      'B07GZFM1ZM': 816,
#      'B008J0Z9TA': 803,
#      'B010BWYDYA': 788,
#      'B0BN74ZJDK': 756},
#     'reference_value': None,
#     'reference_table': None}}]}

# %% [markdown]
# ## Classification metrics (WIP. Do it later when we have negative sampling samples)

# %%
# val_user_indices = val_df["user_indice"].values
# val_item_indices = val_df["item_indice"].values

# %%
# classifications = model.predict(val_user_indices, val_item_indices)

# %%
# min_rel_score = 2
# eval_classification_df = val_df.assign(
#     classification_proba=classifications,
#     label=lambda df: df[args.rating_col].gt(min_rel_score).astype(int),
# )
# eval_classification_df
# Out:
#                                user_id parent_asin  rating  \
# 4668      AGZE3IYHOEGKUTJZSQCSFSQ4IFFQ  B0B787CN26     5.0
# 10425     AEANO5BIASSZNFWNXBR2ECHCPJQQ  B0002MQGOA     5.0
# 10426     AEANO5BIASSZNFWNXBR2ECHCPJQQ  B07HZLHPKP     5.0
# 13265     AHDXCFTV7RS3AM6E2TRPWOG3A33Q  B07QWPVZJY     3.0
# 14423     AEFHRRLFCZQ3TWNYCBA7UD3NIXCA  B00D96J8IM     1.0
# ...                                ...         ...     ...
# 33760091  AHIIISHZP6YAVVHMDEBLJ5CWZ7ZA  B0BZ62FQ13     3.0
# 34470392  AFTE3G43QHXWD3DJGDCI2DHEWQJQ  B08DMXDPW5     5.0
# 35019360  AFENZZDPVUYFVBS47YDOWJCDYBSQ  B09XBT6DS9     4.0
# 35323250  AFMBZYPDAXT5VO3ME67HW5Q5TAOQ  B097KBF8JK     5.0
# 36341797  AEMSEOMPBE6KWOZWCX4VE4E2E7HQ  B00FB45USW     5.0
#
#                        timestamp  user_indice  item_indice  \
# 4668     2021-10-27 19:43:57.873        12159         4440
# 10425    2021-02-02 14:20:48.424          870           59
# 10426    2021-03-08 13:56:57.795          870         3472
# 13265    2021-12-11 00:34:19.152        13529         3630
# 14423    2021-10-17 20:54:19.325         1481         1262
# ...                          ...          ...          ...
# 33760091 2021-07-16 17:08:55.044        14144         4693
# 34470392 2021-01-14 01:48:09.423         7343         3923
# 35019360 2021-12-05 00:35:40.874         5497         4335
# 35323250 2022-02-18 11:32:46.732         6427         4147
# 36341797 2021-08-12 00:42:48.843         2423         1394
#
#           classification_proba  label
# 4668                  0.500000      1
# 10425                 0.993307      1
# 10426                 0.988148      1
# 13265                 0.993307      1
# 14423                 0.993307      0
# ...                        ...    ...
# 33760091              0.993307      1
# 34470392              0.500000      1
# 35019360              0.993307      1
# 35323250              0.500000      1
# 36341797              0.500000      1
#
# [3479 rows x 8 columns]

# %%
# eval_classification_df.loc[lambda df: (df["classification_proba"] > 0.88) & (df["classification_proba"] > 0.5)]
# Out:
#                                user_id parent_asin  rating  \
# 10425     AEANO5BIASSZNFWNXBR2ECHCPJQQ  B0002MQGOA     5.0
# 10426     AEANO5BIASSZNFWNXBR2ECHCPJQQ  B07HZLHPKP     5.0
# 13265     AHDXCFTV7RS3AM6E2TRPWOG3A33Q  B07QWPVZJY     3.0
# 14423     AEFHRRLFCZQ3TWNYCBA7UD3NIXCA  B00D96J8IM     1.0
# 23297     AGK63CGC7N3MB2QN56EZNDZYNGIQ  B07HZLHPKP     3.0
# ...                                ...         ...     ...
# 32499474  AH5HVRS323QOWLMMWCEX3GJXNKLA  B07ZDXHZ6J     1.0
# 32967153  AG3JRUUWEDPQOLULW4QI5LE6LYSQ  B06W2PMP6C     5.0
# 33479788  AE2GH2QNHK6AVGUOTECE6FOECE2A  B091K4WYD1     2.0
# 33760091  AHIIISHZP6YAVVHMDEBLJ5CWZ7ZA  B0BZ62FQ13     3.0
# 35019360  AFENZZDPVUYFVBS47YDOWJCDYBSQ  B09XBT6DS9     4.0
#
#                        timestamp  user_indice  item_indice  \
# 10425    2021-02-02 14:20:48.424          870           59
# 10426    2021-03-08 13:56:57.795          870         3472
# 13265    2021-12-11 00:34:19.152        13529         3630
# 14423    2021-10-17 20:54:19.325         1481         1262
# 23297    2021-01-14 20:35:43.045        10201         3472
# ...                          ...          ...          ...
# 32499474 2021-01-24 15:11:12.439        12657         3784
# 32967153 2021-01-28 17:20:28.043         8393         2881
# 33479788 2021-06-24 18:03:40.116           42         4086
# 33760091 2021-07-16 17:08:55.044        14144         4693
# 35019360 2021-12-05 00:35:40.874         5497         4335
#
#           classification_proba  label
# 10425                 0.993307      1
# 10426                 0.988148      1
# 13265                 0.993307      1
# 14423                 0.993307      0
# 23297                 0.986969      1
# ...                        ...    ...
# 32499474              0.987318      0
# 32967153              0.993307      1
# 33479788              0.993307      0
# 33760091              0.993307      1
# 35019360              0.993307      1
#
# [2441 rows x 8 columns]

# %%
# classification_report = log_classification_metrics(args, eval_classification_df)

# %%
# classification_report.as_dict()
# Out:
# {'metrics': [{'metric': 'ClassificationQualityMetric',
#    'result': {'current': {'accuracy': 0.6498993963782697,
#      'precision': 0.8529291274068005,
#      'recall': 0.7079224753485209,
#      'f1': 0.7736900780379041,
#      'roc_auc': 0.5300361887884277,
#      'log_loss': 0.671690219793583,
#      'tpr': 0.7079224753485209,
#      'tnr': 0.33271375464684017,
#      'fpr': 0.6672862453531598,
#      'fnr': 0.29207752465147907},
#     'reference': None,
#     'target_name': 'label'}},
#   {'metric': 'ClassificationClassBalance', 'result': {}},
#   {'metric': 'ClassificationConfusionMatrix',
#    'result': {'current_matrix': {'labels': [0, 1],
#      'values': [[179, 359], [859, 2082]]},
#     'reference_matrix': None,
#     'target_names': None}},
#   {'metric': 'ClassificationQualityByClass',
#    'result': {'columns': {'utility_columns': {'date': None,
#       'id': None,
#       'target': 'label',
#       'prediction': 'classification_proba'},
#      'num_feature_names': [],
#      'cat_feature_names': [],
#      'text_feature_names': [],
#      'datetime_feature_names': [],
#      'target_names': None},
#     'current': {'metrics': {0: {'precision': 0.1724470134874759,
#        'recall': 0.33271375464684017,
#        'f1': 0.22715736040609136,
#        'support': 538.0},
#       1: {'precision': 0.8529291274068005,
#        'recall': 0.7079224753485209,
#        'f1': 0.7736900780379041,
#        'support': 2941.0}},
#      'roc_aucs': [0.5300361887884276, 0.5300361887884277]},
#     'reference': None}},
#   {'metric': 'ClassificationClassSeparationPlot',
#    'result': {'target_name': 'label'}},
#   {'metric': 'ClassificationProbDistribution', 'result': {}},
#   {'metric': 'ClassificationRocCurve', 'result': {}},
#   {'metric': 'ClassificationPRCurve', 'result': {}},
#   {'metric': 'ClassificationPRTable',
#    'result': {'current': {1: [[5.0, 174.0, 0.99, 142.0, 32.0, 81.6, 4.8],
#       [10.0, 348.0, 0.99, 301.0, 47.0, 86.5, 10.2],
#       [15.0, 522.0, 0.99, 448.0, 74.0, 85.8, 15.2],
#       [20.0, 696.0, 0.99, 597.0, 99.0, 85.8, 20.3],
#       [25.0, 870.0, 0.99, 751.0, 119.0, 86.3, 25.5],
#       [30.0, 1044.0, 0.99, 893.0, 151.0, 85.5, 30.4],
#       [35.0, 1218.0, 0.99, 1043.0, 175.0, 85.6, 35.5],
#       [40.0, 1392.0, 0.99, 1198.0, 194.0, 86.1, 40.7],
#       [45.0, 1566.0, 0.99, 1354.0, 212.0, 86.5, 46.0],
#       [50.0, 1740.0, 0.99, 1502.0, 238.0, 86.3, 51.1],
#       [55.0, 1914.0, 0.98, 1648.0, 266.0, 86.1, 56.0],
#       [60.0, 2088.0, 0.98, 1792.0, 296.0, 85.8, 60.9],
#       [65.0, 2262.0, 0.96, 1936.0, 326.0, 85.6, 65.8],
#       [70.0, 2436.0, 0.88, 2078.0, 358.0, 85.3, 70.7],
#       [75.0, 2610.0, 0.5, 2226.0, 384.0, 85.3, 75.7],
#       [80.0, 2784.0, 0.5, 2374.0, 410.0, 85.3, 80.7],
#       [85.0, 2958.0, 0.5, 2518.0, 440.0, 85.1, 85.6],
#       [90.0, 3132.0, 0.5, 2662.0, 470.0, 85.0, 90.5],
#       [95.0, 3306.0, 0.5, 2803.0, 503.0, 84.8, 95.3],
#       [100.0, 3479.0, 0.5, 2941.0, 538.0, 84.5, 100.0]]},
#     'reference': None}},
#   {'metric': 'ClassificationQualityByFeatureTable',
#    'result': {'target_name': '', 'columns': []}}]}

# %% [markdown]
# ## Persit

# %%
all_params = [args]

if args.log_to_mlflow:
    for params in all_params:
        params_dict = params.model_dump()
        params_ = {f"{params.__repr_name__()}.{k}": v for k, v in params_dict.items() if k != "top_k"}
        mlflow.log_params(params_)

    mlflow.end_run()
# Out:
# 🏃 View run 003-i2i-cf-min-sim-count=4 at: http://localhost:5002/#/experiments/9/runs/56184a6cc7cf4471a294d27474060f06
# 🧪 View experiment at: http://localhost:5002/#/experiments/9

# %%
rec_df.to_csv(os.path.join(args.notebook_persit_dp, "rec_df.csv"), index = False)
